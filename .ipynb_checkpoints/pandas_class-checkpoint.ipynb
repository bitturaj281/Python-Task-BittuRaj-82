# %%
# 1. Data Creation.
# DataFrame()

# %%
import pandas as pd

data={'Name': ["Raj", "Pavn", "Rajvir", "Happy","Jass", "Bobby"],
     "Age": [25, 30, 28, 30, 25, 24],
     "Mobile": ["9876543210", "9123456789", "9988776655","7854454565","9523658596","4525658596"],
     "Marks": [85, 90, 78, 85, 96, 100] 
     }
df = pd.DataFrame(data)
df
# Out:
#      Name  Age      Mobile  Marks
# 0     Raj   25  9876543210     85
# 1    Pavn   30  9123456789     90
# 2  Rajvir   28  9988776655     78
# 3   Happy   30  7854454565     85
# 4     Jaa   25  9523658596     96
# 5   Bobby   24  4525658596    100

# %%
import pandas as pd
import random as rand

data={'SID':[i for i in range(1,7)],
    'Name': ["Raj", "Pavn", "Rajvir", "Happy","Jaa", "Bobby"],
     "Age": [rand.randint(20,35) for _ in range(6)],
     "Marks": [rand.randint(50,100) for _ in range(6)],                               
     "Mobile": [str(rand.randint(9000000000,9999999999)) for _ in range(6)]
     }

df = pd.DataFrame(data)
df = pd.DataFrame(data, index=["row"+str(i) for i in range(1,7)])

# print(df['Name'])
# df["Marks"]
# df.iloc[0:1]
# df.at[2,'Stock_Marktet']
# df.loc[2,'Marks']
# df.iat[2,1]
# df
# df
# Out:
# row1    84
# row2    93
# row3    76
# row4    85
# row5    76
# row6    50
# Name: Marks, dtype: int64

# %%
# Data Acccessing (Selection)
# read_csv()
path = r"D:\Batch82\Python\archive\Finance_data.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)
# df.head(5)
# df.tail()
# df.info()
# df.describe()
# print(df.shape)
# print(df.columns)
# df["Investment_Avenues"]
# df.iloc[4,4]
# df.at[2,'Stock_Marktet']
df.loc[0,'Stock_Marktet']
# Out:
# 'Yes'

# %%
import pandas as pd
path = r"C:\Users\Bittu Raj\Downloads\EWR_Enhanced1.csv"
data =pd.read_csv(path)
df = pd.DataFrame(data)

# df.head(5)
# df.at[0,'Customer_Age']
# df.iloc[0:2,0:1]
# df.at[3,'Customer_Name']
# df.iat[1,3]
# df.at[0,'Customer_Age']
# df.iloc[0:2,11]
df
# Out:
#      Order_ID        Date     Customer_Name  Customer_Age          Product  \
# 0        4644  14-09-2024       Abha Mandal            40          Fiction
# 1        6285  20-03-2024     Saksham Dewan            22       Smartwatch
# 2        2931  16-03-2024      Gautam Samra            31      Moisturizer
# 3        7980  19-12-2024      Rajata Goyal            24       Smartphone
# 4        2407  03-09-2024      Chaaya Swamy            40          Fiction
# ..        ...         ...               ...           ...              ...
# 495      4628  25-06-2024  Leela Narasimhan            60            Shoes
# 496      2866  12-05-2024     Vedika Mander            22      Moisturizer
# 497      1153  10-08-2024     Aadi Bhargava            50     Refrigerator
# 498      7202  28-03-2024  Chakradev Thaker            54            Shoes
# 499      3861  12-12-2024         Anmol Deo            55  Air Conditioner
#
#             Category   Price  Quantity  Total_Sales  Discount (%)  \
# ...

# %%
# Out:
# False

# %%
# Summary
# 1. Create data
# 2. Read CSV
# 3. Selection
# 4. Missing values report.

# %%
# DataFrame check emptiness
import pandas as pd
path = r"C:\Users\Bittu Raj\Downloads\EWR_Enhanced1.csv"
data =pd.read_csv(path)
df = pd.DataFrame(data)
# True if dataframe zero rows.
# empty = df.empty
# empty
# print(len(df)==0)

# %%
# Col emptiness check
import pandas as pd
path = r"C:\Users\Bittu Raj\Downloads\EWR_Enhanced1.csv"
data =pd.read_csv(path)
df = pd.DataFrame(data)
col =df['Customer_name']
print(col.empty)
# Out:
# False

# %%
# Any missing value enywhere.(entire datasheet)
check=df.isna().any().any()
print(check)
# Out:
# False

# %%
# is null for numpy
check=df.isnull().any().any()
print(check)
# Out:
# False

# %%
# column-level checks

# col=df[['Region','Demo_col','Final_sales']].isna()
# print(col)

col=df[['Order_ID']].isna().mean()*100
print(f"Total Empty cols: {col}")
# Out:
# Total Empty cols: Order_ID    0.0
# dtype: float64

# %%
# Row-level checks
r=len(df)
rows=[i for i in range(r)]
print(df.isna().any(axis=1).loc[rows])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
# Summary
# 1. Create Data
# 2. Read csv
# 3. Selection
# 4. Missing cleaning and removing duplicates.
# 5. Apply filter on data

# %%
# 5. Data cleaning and removing duplicates.
import pandas as pd
path = r"D:\Batch82\Python\finance_large.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)
# df = df.isna().any().sum()
# df = df.fillna(0)
# df = df.dropna()

df.tail(50)
# Out:
#     TransactionID        Date   Account        Type  Amount  Balance
# 48           1049  01-02-2025   Savings     Deposit  1075.0  38358.0
# 49           1050  26-01-2025   Savings  Withdrawal  8353.0  44592.0
# 50           1051  19-01-2025    Credit  Withdrawal  4525.0  14764.0
# 51           1052  06-01-2025   Savings     Payment  2219.0  25370.0
# 52           1053  14-01-2025    Credit     Deposit  7889.0  39129.0
# 53           1054  23-01-2025    Credit     Deposit  3508.0  16138.0
# 54           1055  01-01-2025  Checking  Withdrawal  4468.0  15228.0
# 56           1057  20-02-2025   Savings     Payment  6133.0  27039.0
# 57           1058  16-01-2025  Checking     Payment  3332.0  36152.0
# 58           1059  07-02-2025    Credit     Payment  9738.0  32934.0
# 59           1060  17-01-2025   Savings     Payment  2023.0  46149.0
# 60           1061  17-02-2025  Checking     Deposit  7669.0  36791.0
# 61           1062  15-02-2025    Credit  Withdrawal  6104.0  40282.0
# ...

# %%
import pandas as pd
path = r"D:\Batch82\Python\finance_large.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)
# Drop rows only if all columns are NAN
df = df.dropna(how='all')
df
# Out:
#     TransactionID        Date   Account        Type  Amount  Balance
# 0            1001  06-02-2025  Checking  Withdrawal  7583.0   5749.0
# 1            1002  09-02-2025    Credit     Deposit  7990.0  47365.0
# 2            1003  02-01-2025  Checking  Withdrawal  7780.0   6954.0
# 3            1004  05-02-2025   Savings     Payment  2409.0  18407.0
# 4            1005  26-01-2025   Savings     Deposit  5470.0  26770.0
# ..            ...         ...       ...         ...     ...      ...
# 95           1096  11-01-2025  Checking     Deposit  2883.0  34758.0
# 96           1097  16-02-2025  Checking     Payment  7309.0  23877.0
# 97           1098  20-02-2025  Checking  Withdrawal  1510.0  33806.0
# 98           1099  26-02-2025  Checking     Deposit  4999.0  39230.0
# 99           1100  12-01-2025    Credit  Withdrawal  5616.0  29358.0
#
# [100 rows x 6 columns]

# %%
# import pandas as pd
# path = r"D:\Batch82\Python\finance_large.csv"
# data = pd.read_csv(path)
# df = pd.DataFrame(data)
# # Drop rows with NAN in specific column only
# critical = ['Date', 'Type']
# df = df.dropna(subset=critical)
# df

# %%
# import pandas as pd
# path = r"D:\Batch82\Python\finance_large.csv"
# data = pd.read_csv(path)
# df = pd.DataFrame(data)
# # keep rows that have at least N non-NAN values (threshold)
# df = df.dropna(thresh=3) # keep row with >= 3 non-missing values
# df

# %%
# import pandas as pd
# path = r"D:\Batch82\Python\finance_large.csv"
# data = pd.read_csv(path)
# df = pd.DataFrame(data)
# # Drop columns that contains any NAN.
# a = df.dropna(axis=1, how='all')
# a

# %%
# import pandas as pd
# path = r"D:\Batch82\Python\finance_large.csv"
# data = pd.read_csv(path)
# df = pd.DataFrame(data)
# # Drop columns that contains any NAN.
# cols = ['Region', 'payment_method']
# df = df.drop(columns[c for c in cols if[c].isna().any()])
# df

# %%
# 6. Applying filter on data.
import pandas as pd
path = r"D:\Batch82\Python\pandas_practice_sales.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)
# empty_count=(df['Customer_Name'].str.isspace()).sum()
# empty_count
per_col_empty=df.select_dtypes(include='object').apply(lambda col:col.str.isspace()).sum()
per_col_empty
# Out:
# Order_ID           0
# Date               0
# Customer_Name      2
# Product            0
# Category           0
# Total_Sales        0
# Region             0
# Payment_Method     0
# Delivery_Status    0
# dtype: object

# %%
# Filter
import pandas as pd
path = r"D:\Batch82\Python\pandas_practice_sales.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)
# df
# fil=df[df['Customer_Age'] > 40 ]
# fil=df[(df['Customer_Age'] >= 40) & (df['Product']=="Phone Max")]
# fil=df[(df['Customer_Age'] >= 40) | (df['Product']=="Phone Max")]
# fil=df[~(df['Customer_Age'] >= 40)]
# fil=df[df['Customer_Name'].isin(['Aarav Singh', 'Anita Das'])]
# fil=df[df['Price']>50000]
# fil = df.query("Customer_Age < 30")
# fil = df[df["Product"].str.startswith("P")]
# fil = df[df["Customer_Name"].str.startswith("P", na=False, case=True)]
# fil = df[df["Product"].str.endswith("e")]
fil = df[df["Product"].str.contains("e",case=True)]
# fil = df[df["Customer_Age"].between(30,35)]
# fil = df.loc[df['Region']=="North",["Customer_Name","Product"]]
fil
# Out:
#     Order_ID        Date Customer_Name  Customer_Age     Product     Category  \
# 0   ORD-1001  01-06-2025   Aarav Singh          28.0     Phone X  Electronics
# 1   ORD-1002         bad    Riya Verma           NaN     Phone X  Electronics
# 3   ORD-1004  10-06-2025   Aarav Singh          28.0     Phone X  Electronics
# 4   ORD-1005  20-01-2025                        22.0  Phone Case  Accessories
# 5   ORD-1006         NaN           NaN           NaN  Tablet Pro          NaN
# 6   ORD-1007  15-12-2024     Sneha Rao          30.0  Headphones  Electronics
# 7   ORD-1008  05-03-2025       Unknown           NaN  Tablet Pro      Unknown
# 8   ORD-1009  30-06-2025     Anita Das          41.0   Phone Max  Electronics
# 10  ORD-1011  11-02-2025   Meera Joshi          33.0  Phone Case  Accessories
# 12  ORD-1013  01-04-2025    Priya Iyer          29.0  Headphones  Electronics
# 13  ORD-1014  01-07-2025    Rahul Jain          52.0  Tablet Pro  Electronics
# ...

# %%
# Mask And where
import pandas as pd
path = r"D:\Batch82\Python\pandas_practice_sales.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)

# masked = df["Customer_Age"].mask(df['Customer_Age']>40)
# masked

# where = df["Customer_Age"].where(df['Customer_Age']>40)
# where

# fil = df.nlargest(3, "Customer_Age")
# fil

# fil = df.nsmallest(1, "Customer_Age")
# fil

# fil = df.sample(5,random_state=42)
# fil

# age_limit = 30
# fil = df.query('Customer_Age > @age_limit')
# fil

df = df.set_index("Order_ID").sort_index()
df
# Out:
#                 Date Customer_Name  Customer_Age     Product     Category  \
# Order_ID
# ORD-1001  01-06-2025   Aarav Singh          28.0     Phone X  Electronics
# ORD-1002         bad    Riya Verma           NaN     Phone X  Electronics
# ORD-1003  15-05-2025   Kabir Mehta          35.0  Laptop Air  Electronics
# ORD-1004  10-06-2025   Aarav Singh          28.0     Phone X  Electronics
# ORD-1005  20-01-2025                        22.0  Phone Case  Accessories
# ORD-1006         NaN           NaN           NaN  Tablet Pro          NaN
# ORD-1007  15-12-2024     Sneha Rao          30.0  Headphones  Electronics
# ORD-1008  05-03-2025       Unknown           NaN  Tablet Pro      Unknown
# ORD-1009  30-06-2025     Anita Das          41.0   Phone Max  Electronics
# ORD-1010  25-06-2025   Vikram Shah          45.0  Laptop Air  Electronics
# ORD-1011  11-02-2025   Meera Joshi          33.0  Phone Case  Accessories
# ...
